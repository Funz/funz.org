# %%
# install openmodelica from its repository

shell_call <- function(command, ...) { # required for later call of shell...
  result <- system(command, intern = TRUE, ...)
  cat(paste0(result, collapse = "\n"))
}

shell_call('for deb in deb deb-src; do echo "$deb http://build.openmodelica.org/apt `lsb_release -cs` release"; done | sudo tee /etc/apt/sources.list.d/openmodelica.list')
shell_call('wget -q http://build.openmodelica.org/apt/openmodelica.asc -O- | sudo apt-key add -')
shell_call('apt update && apt install openmodelica')

# check 'omc' command
shell_call('omc --help')
# Out:
# deb http://build.openmodelica.org/apt bionic release
# deb-src http://build.openmodelica.org/apt bionic releaseOKHit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Ign:9 http://build.openmodelica.org/apt bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:11 http://build.openmodelica.org/apt bionic Release [26.3 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://build.openmodelica.org/apt bionic Release.gpg [488 B]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [1,038 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,338 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,303 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,496 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,068 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,563 kB]
# Get:23 http://build.openmodelica.org/apt bionic/release amd64 Packages [6,379 B]
# Fetched 13.1 MB in 7s (1,791 kB/s)
# Reading package lists...
# Building dependency tree...
# Reading state information...
# 11 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   aglfn avahi-daemon bind9-host drcontrol drmodelica dvipng
#   fonts-droid-fallback fonts-lmodern fonts-noto-mono geoclue-2.0
#   geoip-database ghostscript gnuplot-data gnuplot-nox groff gsfonts
#   gstreamer1.0-plugins-base iio-sensor-proxy imagemagick imagemagick-6-common
#   imagemagick-6.q16 libaudio2 libavahi-core7 libavahi-glib1 libbind9-160
#   libbrotli1 libcap2-bin libcdparanoia0 libcoin80v5 libcupsfilters1
#   libcupsimage2 libdaemon0 libdjvulibre-text libdjvulibre21 libdns1100
#   libdom4j-java libdvdnav4 libdvdread4 libfaad2 libgeoclue-2-0 libgeoip1
#   libgl1-mesa-glx libgraphicsmagick-q16-3 libgs9 libgs9-common
#   libgstreamer-plugins-base1.0-0 libgstreamer1.0-0 libhyphen0 libijs-0.35
#   libisc169 libisccc160 libisccfg160 libiso9660-10 libjaxen-java libjbig2dec0
#   libjdom1-java libkpathsea6 libldb1 liblqr-1-0 liblua5.3-0 liblwres160
#   libmad0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libmbim-glib4 libmbim-proxy libmm-glib0 libmng2
#   libmodplug1 libmpcdec6 libnetpbm10 libnl-genl-3-200 libnss-mdns libomc
#   libomccpp libomcsimulation libomniorb4-2 libomnithread4 libomp5 libomplot
#   libomsensplugin libomsimulator libopenscenegraph100v5 libopenthreads20
#   liborc-0.4-0 libpam-cap libpoppler-glib8 libpotrace0 libptexenc1
#   libqmi-glib5 libqmi-proxy libqt4-dbus libqt4-declarative libqt4-network
#   libqt4-opengl libqt4-script libqt4-sql libqt4-sql-mysql libqt4-xml
#   libqt4-xmlpatterns libqt5opengl5 libqt5positioning5 libqt5qml5 libqt5quick5
#   libqt5sensors5 libqt5svg5 libqt5webchannel5 libqt5webkit5 libqt5xmlpatterns5
#   libqtcore4 libqtdbus4 libqtgui4 libsaxonb-java libsmbclient libsynctex1
#   libtalloc2 libtdb1 libtevent0 libtexlua52 libtexluajit2 libv4l-0
#   libv4lconvert0 libvcdinfo0 libvisual-0.4-0 libwbclient0 libwmf0.2-7 libwoff1
#   libxerces2-java libxine2 libxine2-bin libxine2-doc libxine2-ffmpeg
#   libxine2-misc-plugins libxine2-plugins libxml-commons-external-java
#   libxml-commons-resolver1.1-java libxom-java libzzip-0-13 lmodern
#   modemmanager netpbm omc omc-common omedit omnotebook omplot omshell
#   omshell-terminal omsimulator poppler-data psutils python-talloc qdbus
#   qt-at-spi qtcore4-l10n samba-libs t1utils tex-common texlive-base
#   texlive-binaries texlive-latex-base usb-modeswitch usb-modeswitch-data
#   wpasupplicant xsltproc
# Suggested packages:
#   avahi-autoipd fonts-noto ghostscript-x gnuplot-doc gvfs imagemagick-doc
#   autotrace cups-bsd | lpr | lprng enscript gimp grads hp2xx html2ps
#   libwmf-bin mplayer povray radiance sane-utils transfig ufraw-batch nas
#   libopenal0a libsimage-dev libdom4j-java-doc libmsv-java libxpp2-java
#   libxpp3-java libdvdcss2 geoip-bin graphicsmagick-dbg libvisual-0.4-plugins
#   gstreamer1.0-tools libjdom1-java-doc inkscape libjxr-tools avahi-autoipd
#   | zeroconf libqt4-declarative-folderlistmodel libqt4-declarative-gestures
#   libqt4-declarative-particles libqt4-declarative-shaders qt4-qmlviewer
#   libqt4-dev qt5-qmltooling-plugins libicu55 qt4-qtconfig libsaxonb-java-doc
#   libwmf0.2-7-gtk libxerces2-java-doc gxine xine-ui
#   libxml-commons-resolver1.1-java-doc libxom-java-doc python-beautifulsoup
#   poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum debhelper perl-tk xpdf-reader | pdf-viewer
#   texlive-latex-base-doc comgt wvdial wpagui libengine-pkcs11-openssl
# The following NEW packages will be installed:
#   aglfn avahi-daemon bind9-host drcontrol drmodelica dvipng
#   fonts-droid-fallback fonts-lmodern fonts-noto-mono geoclue-2.0
#   geoip-database ghostscript gnuplot-data gnuplot-nox groff gsfonts
#   gstreamer1.0-plugins-base iio-sensor-proxy imagemagick imagemagick-6-common
#   imagemagick-6.q16 libaudio2 libavahi-core7 libavahi-glib1 libbind9-160
#   libbrotli1 libcap2-bin libcdparanoia0 libcoin80v5 libcupsfilters1
#   libcupsimage2 libdaemon0 libdjvulibre-text libdjvulibre21 libdns1100
#   libdom4j-java libdvdnav4 libdvdread4 libfaad2 libgeoclue-2-0 libgeoip1
#   libgl1-mesa-glx libgraphicsmagick-q16-3 libgs9 libgs9-common
#   libgstreamer-plugins-base1.0-0 libgstreamer1.0-0 libhyphen0 libijs-0.35
#   libisc169 libisccc160 libisccfg160 libiso9660-10 libjaxen-java libjbig2dec0
#   libjdom1-java libkpathsea6 libldb1 liblqr-1-0 liblua5.3-0 liblwres160
#   libmad0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libmbim-glib4 libmbim-proxy libmm-glib0 libmng2
#   libmodplug1 libmpcdec6 libnetpbm10 libnl-genl-3-200 libnss-mdns libomc
#   libomccpp libomcsimulation libomniorb4-2 libomnithread4 libomp5 libomplot
#   libomsensplugin libomsimulator libopenscenegraph100v5 libopenthreads20
#   liborc-0.4-0 libpam-cap libpoppler-glib8 libpotrace0 libptexenc1
#   libqmi-glib5 libqmi-proxy libqt4-dbus libqt4-declarative libqt4-network
#   libqt4-opengl libqt4-script libqt4-sql libqt4-sql-mysql libqt4-xml
#   libqt4-xmlpatterns libqt5opengl5 libqt5positioning5 libqt5qml5 libqt5quick5
#   libqt5sensors5 libqt5svg5 libqt5webchannel5 libqt5webkit5 libqt5xmlpatterns5
#   libqtcore4 libqtdbus4 libqtgui4 libsaxonb-java libsmbclient libsynctex1
#   libtalloc2 libtdb1 libtevent0 libtexlua52 libtexluajit2 libv4l-0
#   libv4lconvert0 libvcdinfo0 libvisual-0.4-0 libwbclient0 libwmf0.2-7 libwoff1
#   libxerces2-java libxine2 libxine2-bin libxine2-doc libxine2-ffmpeg
#   libxine2-misc-plugins libxine2-plugins libxml-commons-external-java
#   libxml-commons-resolver1.1-java libxom-java libzzip-0-13 lmodern
#   modemmanager netpbm omc omc-common omedit omnotebook omplot omshell
#   omshell-terminal omsimulator openmodelica poppler-data psutils python-talloc
#   qdbus qt-at-spi qtcore4-l10n samba-libs t1utils tex-common texlive-base
#   texlive-binaries texlive-latex-base usb-modeswitch usb-modeswitch-data
#   wpasupplicant xsltproc
# 0 upgraded, 167 newly installed, 0 to remove and 11 not upgraded.
# Need to get 147 MB of archives.
# After this operation, 597 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:2 http://build.openmodelica.org/apt bionic/release amd64 omc-common all 1.19.2-1 [596 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdaemon0 amd64 0.14-6 [16.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6-common all 8:6.9.7.4+dfsg-16ubuntu6.14 [60.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.14 [1,622 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.14 [294 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmng2 amd64 2.0.2-0ubuntu3 [169 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5svg5 amd64 5.9.5-0ubuntu1.1 [129 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcap2-bin amd64 1:2.25-1.2 [20.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer1.0-0 amd64 1.14.5-0ubuntu1~18.04.2 [865 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 liborc-0.4-0 amd64 1:0.4.28-1 [137 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.14.5-0ubuntu1~18.04.3 [689 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhyphen0 amd64 2.8.8-5 [26.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5positioning5 amd64 5.9.5+dfsg-0ubuntu2 [131 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libqt5qml5 amd64 5.9.5-0ubuntu1.1 [1,242 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libqt5quick5 amd64 5.9.5-0ubuntu1.1 [1,201 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5sensors5 amd64 5.9.5-0ubuntu1 [113 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5webchannel5 amd64 5.9.5-0ubuntu1 [47.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbrotli1 amd64 1.0.3-1ubuntu1.3 [262 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwoff1 amd64 1.0.2-1build0.1 [43.0 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5webkit5 amd64 5.212.0~alpha2-7ubuntu1 [11.8 MB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwbclient0 amd64 2:4.7.6+dfsg~ubuntu-0ubuntu2.28 [33.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 tex-common all 6.09 [33.0 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtalloc2 amd64 2.1.10-2ubuntu1 [36.0 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtdb1 amd64 1.3.15-2 [39.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtevent0 amd64 0.9.34-1 [27.7 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldb1 amd64 2:1.2.3-1ubuntu0.2 [114 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-talloc amd64 2.1.10-2ubuntu1 [9,124 B]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 samba-libs amd64 2:4.7.6+dfsg~ubuntu-0ubuntu2.28 [5,255 kB]
# Get:32 http://build.openmodelica.org/apt bionic/release amd64 libomcsimulation amd64 1.19.2-1 [4,871 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsmbclient amd64 2:4.7.6+dfsg~ubuntu-0ubuntu2.28 [54.4 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpam-cap amd64 1:2.25-1.2 [7,268 B]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libisc169 amd64 1:9.11.3+dfsg-1ubuntu1.18 [237 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgeoip1 amd64 1.6.12-1 [71.8 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdns1100 amd64 1:9.11.3+dfsg-1ubuntu1.18 [959 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libisccc160 amd64 1:9.11.3+dfsg-1ubuntu1.18 [17.9 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libisccfg160 amd64 1:9.11.3+dfsg-1ubuntu1.18 [48.3 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbind9-160 amd64 1:9.11.3+dfsg-1ubuntu1.18 [27.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblwres160 amd64 1:9.11.3+dfsg-1ubuntu1.18 [34.5 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 bind9-host amd64 1:9.11.3+dfsg-1ubuntu1.18 [53.5 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 geoip-database all 20180315-1 [2,090 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-core7 amd64 0.7-3.1ubuntu1.3 [81.3 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 avahi-daemon amd64 0.7-3.1ubuntu1.3 [62.4 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libomnithread4 amd64 4.2.2-0.8 [12.9 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libomniorb4-2 amd64 4.2.2-0.8 [1,102 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkpathsea6 amd64 2017.20170613.44572-8ubuntu0.1 [54.9 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libptexenc1 amd64 2017.20170613.44572-8ubuntu0.1 [34.5 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsynctex1 amd64 2017.20170613.44572-8ubuntu0.1 [41.4 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexlua52 amd64 2017.20170613.44572-8ubuntu0.1 [91.2 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexluajit2 amd64 2017.20170613.44572-8ubuntu0.1 [230 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/main amd64 t1utils amd64 1.41-2 [56.0 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.9 [18.6 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.17 [5,092 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.17 [2,267 kB]
# Get:59 http://build.openmodelica.org/apt bionic/release amd64 libomc amd64 1.19.2-1 [6,552 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpotrace0 amd64 1.14-2 [17.4 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libzzip-0-13 amd64 0.13.62-3.1ubuntu0.18.04.1 [26.0 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 texlive-binaries amd64 2017.20170613.44572-8ubuntu0.1 [8,179 kB]
# Get:63 http://build.openmodelica.org/apt bionic/release amd64 omc amd64 1.19.2-1 [124 kB]
# Get:64 http://build.openmodelica.org/apt bionic/release amd64 libomplot amd64 1.19.2-1 [489 kB]
# Get:65 http://build.openmodelica.org/apt bionic/release amd64 omnotebook amd64 1.19.2-1 [301 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.17 [51.3 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dvipng amd64 1.15-1 [78.2 kB]
# Get:68 http://build.openmodelica.org/apt bionic/release amd64 drcontrol all 1.19.2-1 [637 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lmodern all 2.004.5-3 [4,551 kB]
# Get:70 http://build.openmodelica.org/apt bionic/release amd64 drmodelica all 1.19.2-1 [902 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-glib1 amd64 0.7-3.1ubuntu1.3 [7,716 B]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgeoclue-2-0 amd64 2.4.7-1ubuntu1 [25.6 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmm-glib0 amd64 1.10.0-1~ubuntu18.04.2 [179 kB]
# Get:75 http://build.openmodelica.org/apt bionic/release amd64 libomccpp amd64 1.19.2-1 [2,108 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/main amd64 geoclue-2.0 amd64 2.4.7-1ubuntu1 [80.6 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 aglfn all 1.7-3 [29.4 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gnuplot-data all 5.2.2+dfsg1-2ubuntu1 [56.7 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblua5.3-0 amd64 5.3.3-1ubuntu0.18.04.1 [115 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gnuplot-nox amd64 5.2.2+dfsg1-2ubuntu1 [789 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/universe amd64 groff amd64 1.22.3-10 [3,150 kB]
# Get:82 http://build.openmodelica.org/apt bionic/release amd64 libomsensplugin amd64 1.19.2-1 [274 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]
# Get:84 http://build.openmodelica.org/apt bionic/release amd64 libomsimulator amd64 1.19.2-1 [1,401 kB]
# Get:85 http://build.openmodelica.org/apt bionic/release amd64 omedit amd64 1.19.2-1 [2,754 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdparanoia0 amd64 3.10.2+debian-13 [46.7 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvisual-0.4-0 amd64 0.4.0-11 [99.2 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-plugins-base amd64 1.14.5-0ubuntu1~18.04.3 [586 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic/main amd64 iio-sensor-proxy amd64 2.4-2 [45.0 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6.q16 amd64 8:6.9.7.4+dfsg-16ubuntu6.14 [423 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick amd64 8:6.9.7.4+dfsg-16ubuntu6.14 [14.2 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaudio2 amd64 1.9.4-6 [50.3 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-glx amd64 20.0.8-0ubuntu1~18.04.1 [5,532 B]
# Get:94 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcoin80v5 amd64 3.1.4~abc9f50+dfsg3-2 [2,380 kB]
# Get:95 http://build.openmodelica.org/apt bionic/release amd64 omplot amd64 1.19.2-1 [67.5 kB]
# Get:96 http://build.openmodelica.org/apt bionic/release amd64 omshell amd64 1.19.2-1 [48.6 kB]
# Get:97 http://build.openmodelica.org/apt bionic/release amd64 omshell-terminal amd64 1.19.2-1 [19.1 kB]
# Get:98 http://build.openmodelica.org/apt bionic/release amd64 omsimulator amd64 1.19.2-1 [1,025 kB]
# Get:99 http://build.openmodelica.org/apt bionic/release amd64 openmodelica amd64 1.19.2-1 [6,148 B]
# Get:100 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre-text all 3.5.27.1-8ubuntu0.4 [49.4 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre21 amd64 3.5.27.1-8ubuntu0.4 [561 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjaxen-java all 1.1.6-3 [214 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdom4j-java all 2.1.0-2 [309 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdvdread4 amd64 6.0.0-1 [50.6 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdvdnav4 amd64 6.0.0-1 [38.0 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfaad2 amd64 2.8.8-1 [154 kB]
# Get:108 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwmf0.2-7 amd64 0.2.8.4-12 [150 kB]
# Get:109 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libgraphicsmagick-q16-3 amd64 1.3.28-2ubuntu0.1 [1,116 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libiso9660-10 amd64 1.0.0-2ubuntu2 [21.5 kB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libjdom1-java all 1.1.3-2~18.04 [156 kB]
# Get:112 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmad0 amd64 0.15.1b-9ubuntu18.04.1 [64.6 kB]
# Get:113 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3-extra amd64 8:6.9.7.4+dfsg-16ubuntu6.14 [62.2 kB]
# Get:114 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmbim-glib4 amd64 1.18.0-1~ubuntu18.04.1 [91.4 kB]
# Get:115 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmbim-proxy amd64 1.18.0-1~ubuntu18.04.1 [5,572 B]
# Get:116 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmodplug1 amd64 1:0.8.9.0-1 [150 kB]
# Get:117 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmpcdec6 amd64 2:0.1~r495-1 [32.3 kB]
# Get:118 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnetpbm10 amd64 2:10.0-15.3build1 [58.0 kB]
# Get:119 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnl-genl-3-200 amd64 3.2.29-0ubuntu3 [11.2 kB]
# Get:120 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnss-mdns amd64 0.10-8ubuntu1 [21.2 kB]
# Get:121 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libomp5 amd64 5.0.1-1 [234 kB]
# Get:122 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenthreads20 amd64 3.2.3+dfsg1-2ubuntu8 [17.9 kB]
# Get:123 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-glib8 amd64 0.62.0-2ubuntu2.14 [108 kB]
# Get:124 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qtcore4-l10n all 4:4.8.7+dfsg-7ubuntu1 [617 kB]
# Get:125 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqtcore4 amd64 4:4.8.7+dfsg-7ubuntu1 [1,552 kB]
# Get:126 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-xml amd64 4:4.8.7+dfsg-7ubuntu1 [96.1 kB]
# Get:127 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqtdbus4 amd64 4:4.8.7+dfsg-7ubuntu1 [186 kB]
# Get:128 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-network amd64 4:4.8.7+dfsg-7ubuntu1 [562 kB]
# Get:129 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-script amd64 4:4.8.7+dfsg-7ubuntu1 [815 kB]
# Get:130 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-sql amd64 4:4.8.7+dfsg-7ubuntu1 [98.5 kB]
# Get:131 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-xmlpatterns amd64 4:4.8.7+dfsg-7ubuntu1 [1,091 kB]
# Get:132 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-declarative amd64 4:4.8.7+dfsg-7ubuntu1 [1,089 kB]
# Get:133 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqtgui4 amd64 4:4.8.7+dfsg-7ubuntu1 [4,115 kB]
# Get:134 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-opengl amd64 4:4.8.7+dfsg-7ubuntu1 [301 kB]
# Get:135 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxine2-bin amd64 1.2.8-2build2 [1,427 kB]
# Get:136 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxine2-ffmpeg amd64 1.2.8-2build2 [195 kB]
# Get:137 http://archive.ubuntu.com/ubuntu bionic/main amd64 libv4lconvert0 amd64 1.14.2-1 [76.1 kB]
# Get:138 http://archive.ubuntu.com/ubuntu bionic/main amd64 libv4l-0 amd64 1.14.2-1 [41.7 kB]
# Get:139 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvcdinfo0 amd64 0.7.24+dfsg-1 [88.8 kB]
# Get:140 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxine2-misc-plugins amd64 1.2.8-2build2 [559 kB]
# Get:141 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxine2-plugins all 1.2.8-2build2 [6,440 B]
# Get:142 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxine2 amd64 1.2.8-2build2 [1,640 B]
# Get:143 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenscenegraph100v5 amd64 3.2.3+dfsg1-2ubuntu8 [5,826 kB]
# Get:144 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqmi-glib5 amd64 1.22.0-1.2~ubuntu18.04.1 [494 kB]
# Get:145 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqmi-proxy amd64 1.22.0-1.2~ubuntu18.04.1 [5,632 B]
# Get:146 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qdbus amd64 4:4.8.7+dfsg-7ubuntu1 [30.0 kB]
# Get:147 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-dbus amd64 4:4.8.7+dfsg-7ubuntu1 [6,440 B]
# Get:148 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-sql-mysql amd64 4:4.8.7+dfsg-7ubuntu1 [30.5 kB]
# Get:149 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5opengl5 amd64 5.9.5+dfsg-0ubuntu2.6 [132 kB]
# Get:150 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5xmlpatterns5 amd64 5.9.5-0ubuntu1 [916 kB]
# Get:151 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxml-commons-external-java all 1.4.01-3 [240 kB]
# Get:152 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxml-commons-resolver1.1-java all 1.2-9 [91.1 kB]
# Get:153 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxerces2-java all 2.11.0-8 [1,344 kB]
# Get:154 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxom-java all 1.2.10-1 [170 kB]
# Get:155 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsaxonb-java all 9.1.0.8+dfsg-2 [1,999 kB]
# Get:156 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxine2-doc all 1.2.8-2build2 [85.9 kB]
# Get:157 http://archive.ubuntu.com/ubuntu bionic/main amd64 lmodern all 2.004.5-3 [9,631 kB]
# Get:158 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 modemmanager amd64 1.10.0-1~ubuntu18.04.2 [728 kB]
# Get:159 http://archive.ubuntu.com/ubuntu bionic/main amd64 netpbm amd64 2:10.0-15.3build1 [1,017 kB]
# Get:160 http://archive.ubuntu.com/ubuntu bionic/universe amd64 psutils amd64 1.17.dfsg-4 [56.2 kB]
# Get:161 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qt-at-spi amd64 0.4.0-8 [58.6 kB]
# Get:162 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-base all 2017.20180305-1 [18.7 MB]
# Get:163 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-base all 2017.20180305-1 [951 kB]
# Get:164 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 wpasupplicant amd64 2:2.6-15ubuntu2.8 [955 kB]
# Get:165 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xsltproc amd64 1.1.29-5ubuntu0.3 [14.0 kB]
# Get:166 http://archive.ubuntu.com/ubuntu bionic/main amd64 usb-modeswitch-data all 20170806-2 [30.7 kB]
# Get:167 http://archive.ubuntu.com/ubuntu bionic/main amd64 usb-modeswitch amd64 2.5.2+repack0-2ubuntu1 [53.6 kB]
# Preconfiguring packages ...
# Fetched 147 MB in 4s (39.1 MB/s)
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 123991 files and directories currently installed.)
# Preparing to unpack .../000-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package libdaemon0:amd64.
# Preparing to unpack .../001-libdaemon0_0.14-6_amd64.deb ...
# Unpacking libdaemon0:amd64 (0.14-6) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../002-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../003-imagemagick-6-common_8%3a6.9.7.4+dfsg-16ubuntu6.14_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.14) ...
# Selecting previously unselected package libmagickcore-6.q16-3:amd64.
# Preparing to unpack .../004-libmagickcore-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.14_amd64.deb ...
# Unpacking libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.14) ...
# Selecting previously unselected package libmagickwand-6.q16-3:amd64.
# Preparing to unpack .../005-libmagickwand-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.14_amd64.deb ...
# Unpacking libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.14) ...
# Selecting previously unselected package libmng2:amd64.
# Preparing to unpack .../006-libmng2_2.0.2-0ubuntu3_amd64.deb ...
# Unpacking libmng2:amd64 (2.0.2-0ubuntu3) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../007-libqt5svg5_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package libcap2-bin.
# Preparing to unpack .../008-libcap2-bin_1%3a2.25-1.2_amd64.deb ...
# Unpacking libcap2-bin (1:2.25-1.2) ...
# Selecting previously unselected package libgstreamer1.0-0:amd64.
# Preparing to unpack .../009-libgstreamer1.0-0_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../010-liborc-0.4-0_1%3a0.4.28-1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../011-libgstreamer-plugins-base1.0-0_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../012-libhyphen0_2.8.8-5_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-5) ...
# Selecting previously unselected package libqt5positioning5:amd64.
# Preparing to unpack .../013-libqt5positioning5_5.9.5+dfsg-0ubuntu2_amd64.deb ...
# Unpacking libqt5positioning5:amd64 (5.9.5+dfsg-0ubuntu2) ...
# Selecting previously unselected package libqt5qml5:amd64.
# Preparing to unpack .../014-libqt5qml5_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking libqt5qml5:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package libqt5quick5:amd64.
# Preparing to unpack .../015-libqt5quick5_5.9.5-0ubuntu1.1_amd64.deb ...
# Unpacking libqt5quick5:amd64 (5.9.5-0ubuntu1.1) ...
# Selecting previously unselected package libqt5sensors5:amd64.
# Preparing to unpack .../016-libqt5sensors5_5.9.5-0ubuntu1_amd64.deb ...
# Unpacking libqt5sensors5:amd64 (5.9.5-0ubuntu1) ...
# Selecting previously unselected package libqt5webchannel5:amd64.
# Preparing to unpack .../017-libqt5webchannel5_5.9.5-0ubuntu1_amd64.deb ...
# Unpacking libqt5webchannel5:amd64 (5.9.5-0ubuntu1) ...
# Selecting previously unselected package libbrotli1:amd64.
# Preparing to unpack .../018-libbrotli1_1.0.3-1ubuntu1.3_amd64.deb ...
# Unpacking libbrotli1:amd64 (1.0.3-1ubuntu1.3) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../019-libwoff1_1.0.2-1build0.1_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build0.1) ...
# Selecting previously unselected package libqt5webkit5:amd64.
# Preparing to unpack .../020-libqt5webkit5_5.212.0~alpha2-7ubuntu1_amd64.deb ...
# Unpacking libqt5webkit5:amd64 (5.212.0~alpha2-7ubuntu1) ...
# Selecting previously unselected package libwbclient0:amd64.
# Preparing to unpack .../021-libwbclient0_2%3a4.7.6+dfsg~ubuntu-0ubuntu2.28_amd64.deb ...
# Unpacking libwbclient0:amd64 (2:4.7.6+dfsg~ubuntu-0ubuntu2.28) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../022-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../023-tex-common_6.09_all.deb ...
# Unpacking tex-common (6.09) ...
# Selecting previously unselected package libtalloc2:amd64.
# Preparing to unpack .../024-libtalloc2_2.1.10-2ubuntu1_amd64.deb ...
# Unpacking libtalloc2:amd64 (2.1.10-2ubuntu1) ...
# Selecting previously unselected package libtdb1:amd64.
# Preparing to unpack .../025-libtdb1_1.3.15-2_amd64.deb ...
# Unpacking libtdb1:amd64 (1.3.15-2) ...
# Selecting previously unselected package libtevent0:amd64.
# Preparing to unpack .../026-libtevent0_0.9.34-1_amd64.deb ...
# Unpacking libtevent0:amd64 (0.9.34-1) ...
# Selecting previously unselected package libldb1:amd64.
# Preparing to unpack .../027-libldb1_2%3a1.2.3-1ubuntu0.2_amd64.deb ...
# Unpacking libldb1:amd64 (2:1.2.3-1ubuntu0.2) ...
# Selecting previously unselected package python-talloc.
# Preparing to unpack .../028-python-talloc_2.1.10-2ubuntu1_amd64.deb ...
# Unpacking python-talloc (2.1.10-2ubuntu1) ...
# Selecting previously unselected package samba-libs:amd64.
# Preparing to unpack .../029-samba-libs_2%3a4.7.6+dfsg~ubuntu-0ubuntu2.28_amd64.deb ...
# Unpacking samba-libs:amd64 (2:4.7.6+dfsg~ubuntu-0ubuntu2.28) ...
# Selecting previously unselected package libsmbclient:amd64.
# Preparing to unpack .../030-libsmbclient_2%3a4.7.6+dfsg~ubuntu-0ubuntu2.28_amd64.deb ...
# Unpacking libsmbclient:amd64 (2:4.7.6+dfsg~ubuntu-0ubuntu2.28) ...
# Selecting previously unselected package libpam-cap:amd64.
# Preparing to unpack .../031-libpam-cap_1%3a2.25-1.2_amd64.deb ...
# Unpacking libpam-cap:amd64 (1:2.25-1.2) ...
# Selecting previously unselected package libisc169:amd64.
# Preparing to unpack .../032-libisc169_1%3a9.11.3+dfsg-1ubuntu1.18_amd64.deb ...
# Unpacking libisc169:amd64 (1:9.11.3+dfsg-1ubuntu1.18) ...
# Selecting previously unselected package libgeoip1:amd64.
# Preparing to unpack .../033-libgeoip1_1.6.12-1_amd64.deb ...
# Unpacking libgeoip1:amd64 (1.6.12-1) ...
# Selecting previously unselected package libdns1100:amd64.
# Preparing to unpack .../034-libdns1100_1%3a9.11.3+dfsg-1ubuntu1.18_amd64.deb ...
# Unpacking libdns1100:amd64 (1:9.11.3+dfsg-1ubuntu1.18) ...
# Selecting previously unselected package libisccc160:amd64.
# Preparing to unpack .../035-libisccc160_1%3a9.11.3+dfsg-1ubuntu1.18_amd64.deb ...
# Unpacking libisccc160:amd64 (1:9.11.3+dfsg-1ubuntu1.18) ...
# Selecting previously unselected package libisccfg160:amd64.
# Preparing to unpack .../036-libisccfg160_1%3a9.11.3+dfsg-1ubuntu1.18_amd64.deb ...
# Unpacking libisccfg160:amd64 (1:9.11.3+dfsg-1ubuntu1.18) ...
# Selecting previously unselected package libbind9-160:amd64.
# Preparing to unpack .../037-libbind9-160_1%3a9.11.3+dfsg-1ubuntu1.18_amd64.deb ...
# Unpacking libbind9-160:amd64 (1:9.11.3+dfsg-1ubuntu1.18) ...
# Selecting previously unselected package liblwres160:amd64.
# Preparing to unpack .../038-liblwres160_1%3a9.11.3+dfsg-1ubuntu1.18_amd64.deb ...
# Unpacking liblwres160:amd64 (1:9.11.3+dfsg-1ubuntu1.18) ...
# Selecting previously unselected package bind9-host.
# Preparing to unpack .../039-bind9-host_1%3a9.11.3+dfsg-1ubuntu1.18_amd64.deb ...
# Unpacking bind9-host (1:9.11.3+dfsg-1ubuntu1.18) ...
# Selecting previously unselected package geoip-database.
# Preparing to unpack .../040-geoip-database_20180315-1_all.deb ...
# Unpacking geoip-database (20180315-1) ...
# Selecting previously unselected package libavahi-core7:amd64.
# Preparing to unpack .../041-libavahi-core7_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking libavahi-core7:amd64 (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package avahi-daemon.
# Preparing to unpack .../042-avahi-daemon_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking avahi-daemon (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package omc-common.
# Preparing to unpack .../043-omc-common_1.19.2-1_all.deb ...
# Unpacking omc-common (1.19.2-1) ...
# Selecting previously unselected package libomcsimulation:amd64.
# Preparing to unpack .../044-libomcsimulation_1.19.2-1_amd64.deb ...
# Unpacking libomcsimulation:amd64 (1.19.2-1) ...
# Selecting previously unselected package libomnithread4:amd64.
# Preparing to unpack .../045-libomnithread4_4.2.2-0.8_amd64.deb ...
# Unpacking libomnithread4:amd64 (4.2.2-0.8) ...
# Selecting previously unselected package libomniorb4-2:amd64.
# Preparing to unpack .../046-libomniorb4-2_4.2.2-0.8_amd64.deb ...
# Unpacking libomniorb4-2:amd64 (4.2.2-0.8) ...
# Selecting previously unselected package libomc:amd64.
# Preparing to unpack .../047-libomc_1.19.2-1_amd64.deb ...
# Unpacking libomc:amd64 (1.19.2-1) ...
# Selecting previously unselected package omc.
# Preparing to unpack .../048-omc_1.19.2-1_amd64.deb ...
# Unpacking omc (1.19.2-1) ...
# Selecting previously unselected package libomplot:amd64.
# Preparing to unpack .../049-libomplot_1.19.2-1_amd64.deb ...
# Unpacking libomplot:amd64 (1.19.2-1) ...
# Selecting previously unselected package omnotebook.
# Preparing to unpack .../050-omnotebook_1.19.2-1_amd64.deb ...
# Unpacking omnotebook (1.19.2-1) ...
# Selecting previously unselected package drcontrol.
# Preparing to unpack .../051-drcontrol_1.19.2-1_all.deb ...
# Unpacking drcontrol (1.19.2-1) ...
# Selecting previously unselected package drmodelica.
# Preparing to unpack .../052-drmodelica_1.19.2-1_all.deb ...
# Unpacking drmodelica (1.19.2-1) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../053-libkpathsea6_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../054-libptexenc1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libsynctex1:amd64.
# Preparing to unpack .../055-libsynctex1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexlua52:amd64.
# Preparing to unpack .../056-libtexlua52_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../057-libtexluajit2_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../058-t1utils_1.41-2_amd64.deb ...
# Unpacking t1utils (1.41-2) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../059-libcupsimage2_2.2.7-1ubuntu2.9_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.9) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../060-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../061-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../062-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.17_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.17) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../063-libgs9_9.26~dfsg+0-0ubuntu0.18.04.17_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.17) ...
# Selecting previously unselected package libpotrace0.
# Preparing to unpack .../064-libpotrace0_1.14-2_amd64.deb ...
# Unpacking libpotrace0 (1.14-2) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../065-libzzip-0-13_0.13.62-3.1ubuntu0.18.04.1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../066-texlive-binaries_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../067-ghostscript_9.26~dfsg+0-0ubuntu0.18.04.17_amd64.deb ...
# Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.17) ...
# Selecting previously unselected package dvipng.
# Preparing to unpack .../068-dvipng_1.15-1_amd64.deb ...
# Unpacking dvipng (1.15-1) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../069-fonts-lmodern_2.004.5-3_all.deb ...
# Unpacking fonts-lmodern (2.004.5-3) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../070-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package libavahi-glib1:amd64.
# Preparing to unpack .../071-libavahi-glib1_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking libavahi-glib1:amd64 (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package libgeoclue-2-0:amd64.
# Preparing to unpack .../072-libgeoclue-2-0_2.4.7-1ubuntu1_amd64.deb ...
# Unpacking libgeoclue-2-0:amd64 (2.4.7-1ubuntu1) ...
# Selecting previously unselected package libmm-glib0:amd64.
# Preparing to unpack .../073-libmm-glib0_1.10.0-1~ubuntu18.04.2_amd64.deb ...
# Unpacking libmm-glib0:amd64 (1.10.0-1~ubuntu18.04.2) ...
# Selecting previously unselected package geoclue-2.0.
# Preparing to unpack .../074-geoclue-2.0_2.4.7-1ubuntu1_amd64.deb ...
# Unpacking geoclue-2.0 (2.4.7-1ubuntu1) ...
# Selecting previously unselected package aglfn.
# Preparing to unpack .../075-aglfn_1.7-3_all.deb ...
# Unpacking aglfn (1.7-3) ...
# Selecting previously unselected package gnuplot-data.
# Preparing to unpack .../076-gnuplot-data_5.2.2+dfsg1-2ubuntu1_all.deb ...
# Unpacking gnuplot-data (5.2.2+dfsg1-2ubuntu1) ...
# Selecting previously unselected package liblua5.3-0:amd64.
# Preparing to unpack .../077-liblua5.3-0_5.3.3-1ubuntu0.18.04.1_amd64.deb ...
# Unpacking liblua5.3-0:amd64 (5.3.3-1ubuntu0.18.04.1) ...
# Selecting previously unselected package gnuplot-nox.
# Preparing to unpack .../078-gnuplot-nox_5.2.2+dfsg1-2ubuntu1_amd64.deb ...
# Unpacking gnuplot-nox (5.2.2+dfsg1-2ubuntu1) ...
# Selecting previously unselected package groff.
# Preparing to unpack .../079-groff_1.22.3-10_amd64.deb ...
# Unpacking groff (1.22.3-10) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../080-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../081-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../082-libvisual-0.4-0_0.4.0-11_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-11) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../083-gstreamer1.0-plugins-base_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package iio-sensor-proxy.
# Preparing to unpack .../084-iio-sensor-proxy_2.4-2_amd64.deb ...
# Unpacking iio-sensor-proxy (2.4-2) ...
# Selecting previously unselected package imagemagick-6.q16.
# Preparing to unpack .../085-imagemagick-6.q16_8%3a6.9.7.4+dfsg-16ubuntu6.14_amd64.deb ...
# Unpacking imagemagick-6.q16 (8:6.9.7.4+dfsg-16ubuntu6.14) ...
# Selecting previously unselected package imagemagick.
# Preparing to unpack .../086-imagemagick_8%3a6.9.7.4+dfsg-16ubuntu6.14_amd64.deb ...
# Unpacking imagemagick (8:6.9.7.4+dfsg-16ubuntu6.14) ...
# Selecting previously unselected package libaudio2:amd64.
# Preparing to unpack .../087-libaudio2_1.9.4-6_amd64.deb ...
# Unpacking libaudio2:amd64 (1.9.4-6) ...
# Selecting previously unselected package libgl1-mesa-glx:amd64.
# Preparing to unpack .../088-libgl1-mesa-glx_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libcoin80v5.
# Preparing to unpack .../089-libcoin80v5_3.1.4~abc9f50+dfsg3-2_amd64.deb ...
# Unpacking libcoin80v5 (3.1.4~abc9f50+dfsg3-2) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../090-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Selecting previously unselected package libdjvulibre-text.
# Preparing to unpack .../091-libdjvulibre-text_3.5.27.1-8ubuntu0.4_all.deb ...
# Unpacking libdjvulibre-text (3.5.27.1-8ubuntu0.4) ...
# Selecting previously unselected package libdjvulibre21:amd64.
# Preparing to unpack .../092-libdjvulibre21_3.5.27.1-8ubuntu0.4_amd64.deb ...
# Unpacking libdjvulibre21:amd64 (3.5.27.1-8ubuntu0.4) ...
# Selecting previously unselected package libjaxen-java.
# Preparing to unpack .../093-libjaxen-java_1.1.6-3_all.deb ...
# Unpacking libjaxen-java (1.1.6-3) ...
# Selecting previously unselected package libdom4j-java.
# Preparing to unpack .../094-libdom4j-java_2.1.0-2_all.deb ...
# Unpacking libdom4j-java (2.1.0-2) ...
# Selecting previously unselected package libdvdread4:amd64.
# Preparing to unpack .../095-libdvdread4_6.0.0-1_amd64.deb ...
# Unpacking libdvdread4:amd64 (6.0.0-1) ...
# Selecting previously unselected package libdvdnav4:amd64.
# Preparing to unpack .../096-libdvdnav4_6.0.0-1_amd64.deb ...
# Unpacking libdvdnav4:amd64 (6.0.0-1) ...
# Selecting previously unselected package libfaad2:amd64.
# Preparing to unpack .../097-libfaad2_2.8.8-1_amd64.deb ...
# Unpacking libfaad2:amd64 (2.8.8-1) ...
# Selecting previously unselected package libwmf0.2-7:amd64.
# Preparing to unpack .../098-libwmf0.2-7_0.2.8.4-12_amd64.deb ...
# Unpacking libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Selecting previously unselected package libgraphicsmagick-q16-3.
# Preparing to unpack .../099-libgraphicsmagick-q16-3_1.3.28-2ubuntu0.1_amd64.deb ...
# Unpacking libgraphicsmagick-q16-3 (1.3.28-2ubuntu0.1) ...
# Selecting previously unselected package libiso9660-10:amd64.
# Preparing to unpack .../100-libiso9660-10_1.0.0-2ubuntu2_amd64.deb ...
# Unpacking libiso9660-10:amd64 (1.0.0-2ubuntu2) ...
# Selecting previously unselected package libjdom1-java.
# Preparing to unpack .../101-libjdom1-java_1.1.3-2~18.04_all.deb ...
# Unpacking libjdom1-java (1.1.3-2~18.04) ...
# Selecting previously unselected package libmad0:amd64.
# Preparing to unpack .../102-libmad0_0.15.1b-9ubuntu18.04.1_amd64.deb ...
# Unpacking libmad0:amd64 (0.15.1b-9ubuntu18.04.1) ...
# Selecting previously unselected package libmagickcore-6.q16-3-extra:amd64.
# Preparing to unpack .../103-libmagickcore-6.q16-3-extra_8%3a6.9.7.4+dfsg-16ubuntu6.14_amd64.deb ...
# Unpacking libmagickcore-6.q16-3-extra:amd64 (8:6.9.7.4+dfsg-16ubuntu6.14) ...
# Selecting previously unselected package libmbim-glib4:amd64.
# Preparing to unpack .../104-libmbim-glib4_1.18.0-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libmbim-glib4:amd64 (1.18.0-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmbim-proxy.
# Preparing to unpack .../105-libmbim-proxy_1.18.0-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libmbim-proxy (1.18.0-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../106-libmodplug1_1%3a0.8.9.0-1_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-1) ...
# Selecting previously unselected package libmpcdec6:amd64.
# Preparing to unpack .../107-libmpcdec6_2%3a0.1~r495-1_amd64.deb ...
# Unpacking libmpcdec6:amd64 (2:0.1~r495-1) ...
# Selecting previously unselected package libnetpbm10.
# Preparing to unpack .../108-libnetpbm10_2%3a10.0-15.3build1_amd64.deb ...
# Unpacking libnetpbm10 (2:10.0-15.3build1) ...
# Selecting previously unselected package libnl-genl-3-200:amd64.
# Preparing to unpack .../109-libnl-genl-3-200_3.2.29-0ubuntu3_amd64.deb ...
# Unpacking libnl-genl-3-200:amd64 (3.2.29-0ubuntu3) ...
# Selecting previously unselected package libnss-mdns:amd64.
# Preparing to unpack .../110-libnss-mdns_0.10-8ubuntu1_amd64.deb ...
# Unpacking libnss-mdns:amd64 (0.10-8ubuntu1) ...
# Selecting previously unselected package libomp5:amd64.
# Preparing to unpack .../111-libomp5_5.0.1-1_amd64.deb ...
# Unpacking libomp5:amd64 (5.0.1-1) ...
# Selecting previously unselected package libomccpp:amd64.
# Preparing to unpack .../112-libomccpp_1.19.2-1_amd64.deb ...
# Unpacking libomccpp:amd64 (1.19.2-1) ...
# Selecting previously unselected package libomsensplugin:amd64.
# Preparing to unpack .../113-libomsensplugin_1.19.2-1_amd64.deb ...
# Unpacking libomsensplugin:amd64 (1.19.2-1) ...
# Selecting previously unselected package libomsimulator:amd64.
# Preparing to unpack .../114-libomsimulator_1.19.2-1_amd64.deb ...
# Unpacking libomsimulator:amd64 (1.19.2-1) ...
# Selecting previously unselected package libopenthreads20:amd64.
# Preparing to unpack .../115-libopenthreads20_3.2.3+dfsg1-2ubuntu8_amd64.deb ...
# Unpacking libopenthreads20:amd64 (3.2.3+dfsg1-2ubuntu8) ...
# Selecting previously unselected package libpoppler-glib8:amd64.
# Preparing to unpack .../116-libpoppler-glib8_0.62.0-2ubuntu2.14_amd64.deb ...
# Unpacking libpoppler-glib8:amd64 (0.62.0-2ubuntu2.14) ...
# Selecting previously unselected package qtcore4-l10n.
# Preparing to unpack .../117-qtcore4-l10n_4%3a4.8.7+dfsg-7ubuntu1_all.deb ...
# Unpacking qtcore4-l10n (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqtcore4:amd64.
# ...
#                               		:math:`\dot x = Ax + Bu`
#                               		:math:`y = Cx +Du`
#       --intEnumConversion    Allow Integer to enumeration conversion.
#       --profiling            Sets the profiling level to use. Profiled equations and functions record execution time and count for each time step taken by the integrator.
#                                Valid options:
#                                 * none
#                                 * blocks
#                                 * blocks+html
#                                 * all
#                                 * all_perf
#                                 * all_stat
#
#       --reshuffle            sets tolerance of reshuffling algorithm: 1: conservative, 2: more tolerant, 3 resolve all
#       --gDynOpt              Generate dynamic optimization problem based on annotation approach.
#       --maxSizeSolveLinearSystem Max size for solveLinearSystem.
#       --cppFlags             Sets extra flags for compilation with the C++ compiler (e.g. +cppFlags=-O3,-Wall)
#       --removeSimpleEquations Specifies method that removes simple equations.
#                                Valid options:
#                                 * none
#                                 * default
#                                 * causal
#                                 * fastAcausal
#                                 * allAcausal
#                                 * new
#
#       --dynamicTearing       Activates dynamic tearing (TearingSet can be changed automatically during runtime, strict set vs. casual set.)
#                                Valid options:
#                                 * false
#                                 * true
#                                 * linear
#                                 * nonlinear
#
#       --symSolver            Activates symbolic implicit solver (original system is not changed).
#                                Valid options: none, impEuler, expEuler
#       --loop2con             Specifies method that transform loops in constraints. hint: using initial guess from file!
#                                Valid options:
#                                 * none
#                                 * lin
#                                 * noLin
#                                 * all
#
#       --forceTearing         Use tearing set even if it is not smaller than the original component.
#       --simplifyLoops        Simplify algebraic loops.
#                                Valid options:
#                                 * 0
#                                 * 1
#                                 * 2
#
#       --recursiveTearing     Inline and repeat tearing.
#                                Valid options:
#                                 * 0
#                                 * 1
#                                 * 2
#
#       --flowThreshold        Sets the minium threshold for stream flow rates
#       --matrixFormat         Sets the matrix format type in cpp runtime which should be used (dense | sparse ). Default: dense.
#       --partlintorn          Sets the limit for partitionin of linear torn systems.
#       --initOptModules       Sets the initialization optimization modules to use in the back end. See --help=optmodules for more info.
#                                Valid options:
#                                 * calculateStrongComponentJacobians
#                                 * collapseArrayExpressions
#                                 * constantLinearSystem
#                                 * extendDynamicOptimization
#                                 * generateHomotopyComponents
#                                 * inlineHomotopy
#                                 * inputDerivativesUsed
#                                 * recursiveTearing
#                                 * reduceDynamicOptimization
#                                 * replaceHomotopyWithSimplified
#                                 * simplifyAllExpressions
#                                 * simplifyComplexFunction
#                                 * simplifyConstraints
#                                 * simplifyLoops
#                                 * solveSimpleEquations
#                                 * tearingSystem
#                                 * wrapFunctionCalls
#
#       --maxMixedDeterminedIndex Sets the maximum mixed-determined index that is handled by the initialization.
#       --useLocalDirection    Keeps the input/output prefix for all variables in the flat model, not only top-level ones.
#       --defaultOptModulesOrdering If this is activated, then the specified pre-/post-/init-optimization modules will be rearranged to the recommended ordering.
#       --preOptModules+       Enables additional pre-optimization modules, e.g. --preOptModules+=module1,module2 would additionally enable module1 and module2. See --help=optmodules for more info.
#       --preOptModules-       Disables a list of pre-optimization modules, e.g. --preOptModules-=module1,module2 would disable module1 and module2. See --help=optmodules for more info.
#       --postOptModules+      Enables additional post-optimization modules, e.g. --postOptModules+=module1,module2 would additionally enable module1 and module2. See --help=optmodules for more info.
#       --postOptModules-      Disables a list of post-optimization modules, e.g. --postOptModules-=module1,module2 would disable module1 and module2. See --help=optmodules for more info.
#       --initOptModules+      Enables additional init-optimization modules, e.g. --initOptModules+=module1,module2 would additionally enable module1 and module2. See --help=optmodules for more info.
#       --initOptModules-      Disables a list of init-optimization modules, e.g. --initOptModules-=module1,module2 would disable module1 and module2. See --help=optmodules for more info.
#       --instCacheSize        Sets the size of the internal hash table used for instantiation caching.
#       --maxSizeLinearTearing Sets the maximum system size for tearing of linear systems (default 200).
#       --maxSizeNonlinearTearing Sets the maximum system size for tearing of nonlinear systems (default 10000).
#       --noTearingForComponent Deactivates tearing for the specified components.
#                               Use '-d=tearingdump' to find out the relevant indexes.
#       --daeMode              Generates code to simulate models in DAE mode. The whole system is passed directly to the DAE solver SUNDIALS/IDA and no algebraic solver is involved in the simulation process.
#       --inlineMethod         Sets the inline method to use.
#                               replace : This method inlines by replacing in place all expressions. Might lead to very long expression.
#                               append  : This method inlines by adding additional variables to the whole system. Might lead to much bigger system.
#                                Valid options: replace, append
#       --setTearingVars       Sets the tearing variables by its strong component indexes. Use '-d=tearingdump' to find out the relevant indexes.
#                               Use following format: '--setTearingVars=(sci,n,t1,...,tn)*', with sci = strong component index, n = number of tearing variables, t1,...tn = tearing variables.
#                               E.g.: '--setTearingVars=4,2,3,5' would select variables 3 and 5 in strong component 4.
#       --setResidualEqns      Sets the residual equations by its strong component indexes. Use '-d=tearingdump' to find out the relevant indexes for the collective equations.
#                               Use following format: '--setResidualEqns=(sci,n,r1,...,rn)*', with sci = strong component index, n = number of residual equations, r1,...rn = residual equations.
#                               E.g.: '--setResidualEqns=4,2,3,5' would select equations 3 and 5 in strong component 4.
#                               Only works in combination with 'setTearingVars'.
#       --ignoreCommandLineOptionsAnnotation Ignores the command line options specified as annotation in the class.
#       --calculateSensitivities Generates sensitivities variables and matrixes.
#   -r, --alarm                Sets the number seconds until omc timeouts and exits. Used by the testing framework to terminate infinite running processes.
#       --totalTearing         Activates total tearing (determination of all possible tearing sets) for the specified components.
#                               Use '-d=tearingdump' to find out the relevant indexes.
#       --ignoreSimulationFlagsAnnotation Ignores the simulation flags specified as annotation in the class.
#       --dynamicTearingForInitialization Enable Dynamic Tearing also for the initialization system.
#       --preferTVarsWithStartValue Prefer tearing variables with start value for initialization.
#       --equationsPerFile     Generate code for at most this many equations per C-file (partially implemented in the compiler).
#       --evaluateFinalParameters Evaluates all the final parameters in addition to parameters with annotation(Evaluate=true).
#       --evaluateProtectedParameters Evaluates all the protected parameters in addition to parameters with annotation(Evaluate=true).
#       --replaceEvaluatedParameters Replaces all the evaluated parameters in the DAE.
#       --condenseArrays       Sets whether array expressions containing function calls are condensed or not.
#       --wfcAdvanced          wrapFunctionCalls ignores more then default cases, e.g. exp, sin, cos, log, (experimental flag)
#       --tearingStrictness    Sets the strictness of the tearing method regarding the solvability restrictions.
#                                Valid options:
#                                 * casual
#                                 * strict
#                                 * veryStrict
#
#       --interactive          Sets the interactive mode for omc.
#                                Valid options:
#                                 * none
#                                 * corba
#                                 * tcp
#                                 * zmq
#
#   -z, --zeroMQFileSuffix     Sets the file suffix for zeroMQ port file if --interactive=zmq is used.
#       --homotopyApproach     Sets the homotopy approach.
#                                Valid options:
#                                 * equidistantLocal
#                                 * adaptiveLocal
#                                 * equidistantGlobal
#                                 * adaptiveGlobal
#
#       --ignoreReplaceable    Sets whether to ignore replaceability or not when redeclaring.
#       --postOptModulesDAE    Sets the optimization modules for the DAEmode in the back end. See --help=optmodules for more info.
#       --evalLoopLimit        The loop iteration limit used when evaluating constant function calls.
#       --evalRecursionLimit   The recursion limit used when evaluating constant function calls.
#       --singleInstanceAglSolver Sets to instantiate only  one algebraic loop solver all algebraic loops
#       --showStructuralAnnotations Show annotations affecting the solution process in the flattened code.
#       --initialStateSelection Activates the state selection inside initialization to avoid singularities.
#       --linearizationDumpLanguage Sets the target language for the produced code of linearization. Only works with '--generateSymbolicLinearization' and 'linearize(modelName)'.
#                                Valid options: modelica, matlab, julia, python
#       --noASSC               Disables analytical to structural singularity conversion.
#       --fullASSC             Enables full equation replacement for BLT transformation from the ASSC algorithm.
#       --realASSC             Enables the ASSC algorithm to evaluate real valued coefficients (usually only integers).
#       --initASSC             Enables the ASSC algorithm for initialization.
#       --maxSizeASSC          Sets the maximum system size for the analytical to structural conversion algorithm (default 200).
#   -f, --flatModelica         Outputs experimental flat Modelica.
#       --fmiFilter            Specifies which model variables are exposed by the modelDescription.xml
#                                Valid options:
#                                 * none
#                                 * internal
#                                 * protected
#                                 * blackBox
#
#       --fmiSources           Defines if FMUs will be exported with sources or not. --fmiFilter=blackBox might override this, because black box FMUs do never contain their source code.
#       --fmiFlags             Add simulation flags to FMU. Will create <fmiPrefix>_flags.json in resources folder with given flags. Use --fmiFlags or --fmiFlags=none to disable [default]. Use --fmiFlags=default for the default simulation flags. To pass flags use e.g. --fmiFlags=s:cvode,nls:homotopy or --fmiFlags=path/to/yourFlags.json.
#       --fmuCMakeBuild        Defines if FMUs will be configured and build with CMake.
#                                Valid options:
#                                 * default
#                                 * true
#                                 * false
#
#       --newBackend           Activates experimental new backend for better array handling. This also activates the new frontend. [WIP]
#       --parmodauto           Experimental: Enable parallelization of independent systems of equations in the translated model.
#       --interactivePort      Sets the port used by the interactive server.
#       --allowNonStandardModelica Flags to allow non-standard Modelica.
#                                Valid options:
#                                 * nonStdMultipleExternalDeclarations
#                                 * nonStdEnumerationAsIntegers
#                                 * nonStdIntegersAsEnumeration
#                                 * nonStdDifferentCaseFileVsClassName
#
#       --exportClocksInModelDescription exports clocks in modeldescription.xml for fmus, The default is false.
#       --linkType             Sets the link type for the simulation executable.
#                               dynamic: libraries are dynamically linked; the executable is built very fast but is not portable because of DLL dependencies.
#                               static: libraries are statically linked; the executable is built more slowly but it is portable and dependency-free.
#                                Valid options: dynamic, static
#       --tearingAlwaysDer     Always choose state derivatives as iteration variables in strong components.
#       --dumpFlatModel        Dumps the flat model at the given stages of the frontend.
#                                Valid options:
#                                 * flatten
#                                 * connections
#                                 * eval
#                                 * simplify
#                                 * scalarize
#
#   -u, --simulation           Simulates the last model in the given Modelica file.
#
# For more details on a specific topic, use --help=topics or help("topics")
#
# * Examples:
#   omc Model.mo             will produce flattened Model on standard output.
#   omc -s Model.mo          will produce simulation code for the model:
#                             * Model.c           The model C code.
#                             * Model_functions.c The model functions C code.
#                             * Model.makefile    The makefile to compile the model.
#                             * Model_init.xml    The initial values.
#   omc Script.mos           will run the commands from Script.mos.
#   omc Model.mo Modelica    will first load the Modelica library and then produce
#                             flattened Model on standard output.
#   omc Model1.mo Model2.mo  will load both Model1.mo and Model2.mo, and produce
#                             flattened Model1 on standard output.
#   *.mo (Modelica files)
#   *.mos (Modelica Script files)
#
# For available simulation flags, use --help=simulation.
#
# Documentation is available in the built-in package OpenModelica.Scripting or
# online <https://build.openmodelica.org/Documentation/OpenModelica.Scripting.html>.

# %%
# install Funz through devtools
devtools::install_github('Funz/Funz.R')
library(Funz)
# Out:
# Downloading GitHub repo Funz/Funz.R@HEAD
# iterators (NA -> 1.0.14) [CRAN]
# foreach   (NA -> 1.5.2 ) [CRAN]
# Rserve    (NA -> 1.8-10) [CRAN]
# rJava     (NA -> 1.0-6 ) [CRAN]
# Installing 4 packages: iterators, foreach, Rserve, rJava
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# * checking for file ‘/tmp/Rtmp4QcX3b/remotes4c6f9c0065/Funz-Funz.R-77484ce/DESCRIPTION’ ... OK
# * preparing ‘Funz’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building ‘Funz_1.15-0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: rJava

# %%
# install plugin to support Modelica I/O
install.Model('Modelica', edit.script=FALSE)
# Out:
# ...........
# Installed Funz model Modelica

# %%
# setup main input file
writeLines(con='NewtonCooling.mo',text=c(
'// @ref http://book.xogeny.com/behavior/equations/physical/',
'model NewtonCooling "An example of Newton s law of cooling"',
'  parameter Real T_inf=25 "Ambient temperature";',
'  parameter Real T0=90 "Initial temperature";',
'  parameter Real h=0.7 "Convective cooling coefficient";',
'  parameter Real A=1.0 "Surface area";',
'  parameter Real m=0.1 "Mass of thermal capacitance";',
'  parameter Real c_p=1.2 "Specific heat";',
'  Real T "Temperature";',
'initial equation',
'  T = T0 "Specify initial value for T";',
'equation',
'  m*c_p*der(T) = h*A*(T_inf-T) "Newton s law of cooling";',
'end NewtonCooling;'
))

# %%
# wake up the Funz 'daemon' which will provide calculation services:
startCalculators(1)
# Out:
# [[1]]
# PROCESS 'bash', running, pid 11274.

# %%
# run this file with Funz (that will check everything is ok for later parametric study)
Run(model="Modelica",input.files="NewtonCooling.mo")
# Out:
# Using default input design.
# Using default output expressions: T time
# Using archive directory: /content
#  Over.
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# $time
# $time[[1]]
# [1] "[0, 0.002, 0.004, 0.006, 0.008, 0.01, 0.012, 0.014, 0.016, 0.018, 0.02, 0.022, 0.024, 0.026, 0.028, 0.03, 0.032, 0.034, 0.036, 0.038, 0.04, 0.042, 0.044, 0.046, 0.048, 0.05, 0.052, 0.054, 0.056, 0.058, 0.06, 0.062, 0.064, 0.066, 0.068, 0.07000000000000001, 0.07199999999999999, 0.074, 0.076, 0.078, 0.08, 0.082, 0.08400000000000001, 0.08599999999999999, 0.08799999999999999, 0.09, 0.092, 0.094, 0.096, 0.098, 0.1, 0.102, 0.104, 0.106, 0.108, 0.11, 0.112, 0.114, 0.116, 0.118, 0.12, 0.122, 0.124, 0.126, 0.128, 0.13, 0.132, 0.134, 0.136, 0.138, 0.14, 0.142, 0.144, 0.146, 0.148, 0.15, 0.152, 0.154, 0.156, 0.158, 0.16, 0.162, 0.164, 0.166, 0.168, 0.17, 0.172, 0.174, 0.176, 0.178, 0.18, 0.182, 0.184, 0.186, 0.188, 0.19, 0.192, 0.194, 0.196, 0.198, 0.2, 0.202, 0.204, 0.206, 0.208, 0.21, 0.212, 0.214, 0.216, 0.218, 0.22, 0.222, 0.224, 0.226, 0.228, 0.23, 0.232, 0.234, 0.236, 0.238, 0.24, 0.242, 0.244, 0.246, 0.248, 0.25, 0.252, 0.254, 0.256, 0.258, 0.26, 0.262, 0.264, 0.266, 0.268, 0.27, 0.272, 0.274, 0.276, 0.278, 0.28, 0.282, 0.284, 0.286, 0.288, 0.29, 0.292, 0.294, 0.296, 0.298, 0.3, 0.302, 0.304, 0.306, 0.308, 0.31, 0.312, 0.314, 0.316, 0.318, 0.32, 0.322, 0.324, 0.326, 0.328, 0.33, 0.332, 0.334, 0.336, 0.338, 0.34, 0.342, 0.344, 0.346, 0.348, 0.35, 0.352, 0.354, 0.356, 0.358, 0.36, 0.362, 0.364, 0.366, 0.368, 0.37, 0.372, 0.374, 0.376, 0.378, 0.38, 0.382, 0.384, 0.386, 0.388, 0.39, 0.392, 0.394, 0.396, 0.398, 0.4, 0.402, 0.404, 0.406, 0.408, 0.41, 0.412, 0.414, 0.416, 0.418, 0.42, 0.422, 0.424, 0.426, 0.428, 0.43, 0.432, 0.434, 0.436, 0.438, 0.44, 0.442, 0.444, 0.446, 0.448, 0.45, 0.452, 0.454, 0.456, 0.458, 0.46, 0.462, 0.464, 0.466, 0.468, 0.47, 0.472, 0.474, 0.476, 0.478, 0.48, 0.482, 0.484, 0.486, 0.488, 0.49, 0.492, 0.494, 0.496, 0.498, 0.5, 0.502, 0.504, 0.506, 0.508, 0.51, 0.512, 0.514, 0.516, 0.518, 0.52, 0.522, 0.524, 0.526, 0.528, 0.53, 0.532, 0.534, 0.536, 0.538, 0.54, 0.542, 0.544, 0.546, 0.548, 0.55, 0.552, 0.554, 0.556, 0.5580000000000001, 0.5600000000000001, 0.5620000000000001, 0.5639999999999999, 0.5659999999999999, 0.5679999999999999, 0.57, 0.572, 0.574, 0.576, 0.578, 0.58, 0.582, 0.584, 0.586, 0.588, 0.59, 0.592, 0.594, 0.596, 0.598, 0.6, 0.602, 0.604, 0.606, 0.608, 0.61, 0.612, 0.614, 0.616, 0.618, 0.62, 0.622, 0.624, 0.626, 0.628, 0.63, 0.632, 0.634, 0.636, 0.638, 0.64, 0.642, 0.644, 0.646, 0.648, 0.65, 0.652, 0.654, 0.656, 0.658, 0.66, 0.662, 0.664, 0.666, 0.668, 0.67, 0.672, 0.674, 0.676, 0.678, 0.68, 0.6820000000000001, 0.6840000000000001, 0.6860000000000001, 0.6879999999999999, 0.6899999999999999, 0.6919999999999999, 0.694, 0.696, 0.698, 0.7, 0.702, 0.704, 0.706, 0.708, 0.71, 0.712, 0.714, 0.716, 0.718, 0.72, 0.722, 0.724, 0.726, 0.728, 0.73, 0.732, 0.734, 0.736, 0.738, 0.74, 0.742, 0.744, 0.746, 0.748, 0.75, 0.752, 0.754, 0.756, 0.758, 0.76, 0.762, 0.764, 0.766, 0.768, 0.77, 0.772, 0.774, 0.776, 0.778, 0.78, 0.782, 0.784, 0.786, 0.788, 0.79, 0.792, 0.794, 0.796, 0.798, 0.8, 0.802, 0.804, 0.806, 0.8080000000000001, 0.8100000000000001, 0.8120000000000001, 0.8139999999999999, 0.8159999999999999, 0.8179999999999999, 0.82, 0.822, 0.824, 0.826, 0.828, 0.83, 0.832, 0.834, 0.836, 0.838, 0.84, 0.842, 0.844, 0.846, 0.848, 0.85, 0.852, 0.854, 0.856, 0.858, 0.86, 0.862, 0.864, 0.866, 0.868, 0.87, 0.872, 0.874, 0.876, 0.878, 0.88, 0.882, 0.884, 0.886, 0.888, 0.89, 0.892, 0.894, 0.896, 0.898, 0.9, 0.902, 0.904, 0.906, 0.908, 0.91, 0.912, 0.914, 0.916, 0.918, 0.92, 0.922, 0.924, 0.926, 0.928, 0.93, 0.9320000000000001, 0.9340000000000001, 0.9360000000000001, 0.9379999999999999, 0.9399999999999999, 0.9419999999999999, 0.944, 0.946, 0.948, 0.95, 0.952, 0.954, 0.956, 0.958, 0.96, 0.962, 0.964, 0.966, 0.968, 0.97, 0.972, 0.974, 0.976, 0.978, 0.98, 0.982, 0.984, 0.986, 0.988, 0.99, 0.992, 0.994, 0.996, 0.998, 1, 1]"
#
#
# $T
# $T[[1]]
#   [1] 90.00000 89.24607 88.50086 87.76422 87.03614 86.31625 85.60462 84.90127
#   [9] 84.20620 83.51839 82.83815 82.16568 81.50097 80.84403 80.19486 79.55345
#  [17] 78.91980 78.29263 77.67203 77.05873 76.45271 75.85399 75.26255 74.67841
#  [25] 74.10155 73.53084 72.96541 72.40666 71.85456 71.30913 70.77036 70.23825
#  [33] 69.71281 69.19345 68.67845 68.16953 67.66667 67.16989 66.67917 66.19452
#  [41] 65.71593 65.24336 64.77532 64.31280 63.85574 63.40409 62.95778 62.51676
#  [49] 62.08096 61.65034 61.22482 60.80435 60.38887 59.97833 59.57265 59.17179
#  [57] 58.77569 58.38428 57.99744 57.61513 57.23731 56.86394 56.49493 56.13025
#  [65] 55.76982 55.41358 55.06148 54.71346 54.36944 54.02938 53.69321 53.36088
#  [73] 53.03232 52.70746 52.38644 52.06957 51.75636 51.44675 51.14069 50.83813
#  [81] 50.53901 50.24328 49.95090 49.66179 49.37592 49.09323 48.81366 48.53716
#  [89] 48.26369 47.99317 47.72557 47.46186 47.20128 46.94367 46.68900 46.43721
#  [97] 46.18826 45.94213 45.69876 45.45811 45.22014 44.98482 44.75209 44.52193
# [105] 44.29428 44.06911 43.84637 43.62652 43.40963 43.19524 42.98332 42.77384
# [113] 42.56675 42.36204 42.15968 41.95962 41.76185 41.56632 41.37302 41.18190
# [121] 40.99294 40.80611 40.62137 40.43875 40.25864 40.08064 39.90474 39.73092
# [129] 39.55916 39.38944 39.22174 39.05605 38.89234 38.73061 38.57082 38.41298
# [137] 38.25705 38.10303 37.95090 37.80065 37.65202 37.50508 37.35990 37.21645
# [145] 37.07471 36.93467 36.79630 36.65958 36.52450 36.39104 36.25917 36.12888
# [153] 36.00014 35.87294 35.74726 35.62309 35.50036 35.37902 35.25910 35.14058
# [161] 35.02344 34.90767 34.79323 34.68012 34.56831 34.45778 34.34851 34.24048
# [169] 34.13368 34.02807 33.92365 33.82039 33.71827 33.61746 33.51779 33.41926
# [177] 33.32185 33.22553 33.13030 33.03614 32.94304 32.85097 32.75994 32.66992
# [185] 32.58090 32.49287 32.40582 32.31972 32.23457 32.15044 32.06730 31.98511
# [193] 31.90385 31.82351 31.74410 31.66559 31.58798 31.51127 31.43544 31.36049
# [201] 31.28642 31.21322 31.14087 31.06939 30.99875 30.92894 30.85986 30.79158
# [209] 30.72411 30.65744 30.59155 30.52645 30.46213 30.39857 30.33579 30.27376
# [217] 30.21250 30.15198 30.09221 30.03319 29.97490 29.91735 29.86036 29.80402
# [225] 29.74835 29.69335 29.63901 29.58531 29.53226 29.47985 29.42806 29.37690
# [233] 29.32634 29.27640 29.22705 29.17829 29.13012 29.08252 29.03551 28.98907
# [241] 28.94320 28.89787 28.85308 28.80884 28.76512 28.72192 28.67923 28.63705
# [249] 28.59537 28.55418 28.51348 28.47325 28.43350 28.39420 28.35536 28.31697
# [257] 28.27901 28.24149 28.20440 28.16772 28.13146 28.09560 28.06013 28.02505
# [265] 27.99036 27.95604 27.92208 27.88849 27.85524 27.82234 27.78978 27.75791
# [273] 27.72659 27.69564 27.66506 27.63484 27.60497 27.57545 27.54628 27.51745
# [281] 27.48896 27.46079 27.43294 27.40541 27.37820 27.35129 27.32469 27.29838
# [289] 27.27236 27.24662 27.22117 27.19599 27.17108 27.14644 27.12205 27.09792
# [297] 27.07403 27.05039 27.02698 27.00381 26.98086 26.95813 26.93562 26.91331
# [305] 26.89169 26.87037 26.84929 26.82844 26.80784 26.78746 26.76731 26.74739
# [313] 26.72768 26.70819 26.68891 26.66984 26.65097 26.63230 26.61382 26.59554
# [321] 26.57744 26.55953 26.54179 26.52424 26.50685 26.48963 26.47257 26.45568
# [329] 26.43894 26.42235 26.40591 26.38961 26.37345 26.35778 26.34240 26.32721
# [337] 26.31219 26.29734 26.28266 26.26814 26.25379 26.23961 26.22558 26.21171
# [345] 26.19799 26.18443 26.17102 26.15775 26.14463 26.13165 26.11881 26.10611
# [353] 26.09354 26.08111 26.06881 26.05663 26.04458 26.03265 26.02084 26.00916
# [361] 25.99758 25.98612 25.97488 25.96385 25.95295 25.94217 25.93151 25.92098
# [369] 25.91056 25.90026 25.89008 25.88001 25.87005 25.86021 25.85047 25.84084
# [377] 25.83131 25.82189 25.81256 25.80334 25.79422 25.78519 25.77626 25.76741
# [385] 25.75866 25.75000 25.74143 25.73294 25.72453 25.71621 25.70797 25.69987
# [393] 25.69194 25.68411 25.67636 25.66870 25.66113 25.65365 25.64625 25.63894
# [401] 25.63170 25.62455 25.61748 25.61048 25.60356 25.59672 25.58995 25.58326
# [409] 25.57663 25.57008 25.56360 25.55719 25.55084 25.54456 25.53834 25.53219
# [417] 25.52610 25.52007 25.51410 25.50818 25.50235 25.49666 25.49103 25.48547
# [425] 25.47997 25.47454 25.46916 25.46385 25.45860 25.45340 25.44827 25.44319
# [433] 25.43816 25.43320 25.42828 25.42342 25.41862 25.41386 25.40916 25.40451
# [441] 25.39990 25.39534 25.39083 25.38637 25.38195 25.37758 25.37325 25.36897
# [449] 25.36472 25.36052 25.35641 25.35235 25.34832 25.34435 25.34041 25.33652
# [457] 25.33267 25.32887 25.32511 25.32138 25.31770 25.31406 25.31046 25.30690
# [465] 25.30338 25.29989 25.29644 25.29303 25.28966 25.28633 25.28303 25.27976
# [473] 25.27654 25.27334 25.27019 25.26706 25.26397 25.26092 25.25789 25.25491
# [481] 25.25195 25.24903 25.24614 25.24329 25.24046 25.23767 25.23490 25.23217
# [489] 25.22947 25.22680 25.22416 25.22155 25.21897 25.21642 25.21390 25.21141
# [497] 25.20894 25.20651 25.20410 25.20172 25.19938 25.19938
#
#
# $state
# $state[[1]]
# [1] "done"
#
#
# $duration
# $duration[[1]]
# [1] 6
#
#
# $calc
# $calc[[1]]
# [1] "localhost:34461"

# %%
# setup main parametrized (with `$convection`) input file
writeLines(con='NewtonCooling.mo.par',text=c(
'// @ref http://book.xogeny.com/behavior/equations/physical/',
'model NewtonCooling "An example of Newton s law of cooling"',
'  parameter Real T_inf=25 "Ambient temperature";',
'  parameter Real T0=90 "Initial temperature";',
'  parameter Real h=$convection "Convective cooling coefficient";',
'  parameter Real A=1.0 "Surface area";',
'  parameter Real m=0.1 "Mass of thermal capacitance";',
'  parameter Real c_p=1.2 "Specific heat";',
'  Real T "Temperature";',
'initial equation',
'  T = T0 "Specify initial value for T";',
'equation',
'  m*c_p*der(T) = h*A*(T_inf-T) "Newton s law of cooling";',
'end NewtonCooling;'
))

# %%
# launch 6 calculations for different `convection` values (0.5, 0.6, 0.7, 0.8, 0.9, 1.0)
Run(model="Modelica",input.files="NewtonCooling.mo.par", input.variables=list(convection=c(0.5,0.6,0.7,0.8,0.9,1.0)), output.expressions="min(T)")
# Out:
# Using archive directory: /content
#  Over.
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# $convection
# $convection[[1]]
# [1] 0.5
#
# $convection[[2]]
# [1] 0.6
#
# $convection[[3]]
# [1] 0.7
#
# $convection[[4]]
# [1] 0.8
#
# $convection[[5]]
# [1] 0.9
#
# $convection[[6]]
# [1] 1
#
#
# $`min(T)`
# $`min(T)`[[1]]
# [1] 25.98653
#
# $`min(T)`[[2]]
# [1] 25.43374
#
# $`min(T)`[[3]]
# [1] 25.19938
#
# $`min(T)`[[4]]
# [1] 25.08829
#
# $`min(T)`[[5]]
# [1] 25.04046
#
# $`min(T)`[[6]]
# [1] 25.01947
#
#
# $state
# $state[[1]]
# [1] "done"
#
# $state[[2]]
# [1] "done"
#
# $state[[3]]
# [1] "done"
#
# $state[[4]]
# [1] "done"
#
# $state[[5]]
# [1] "done"
#
# $state[[6]]
# [1] "done"
#
#
# $duration
# $duration[[1]]
# [1] 3
#
# $duration[[2]]
# [1] 3
#
# $duration[[3]]
# [1] 3
#
# $duration[[4]]
# [1] 3
#
# $duration[[5]]
# [1] 3
#
# $duration[[6]]
# [1] 3
#
#
# $calc
# $calc[[1]]
# [1] "localhost:42323"
#
# $calc[[2]]
# [1] "localhost:42323"
#
# $calc[[3]]
# [1] "localhost:42323"
#
# $calc[[4]]
# [1] "localhost:42323"
#
# $calc[[5]]
# [1] "localhost:42323"
#
# $calc[[6]]
# [1] "localhost:42323"

# %%
# install Brent root finding algorithm
install.Design('Brent')
# Out:
# ...........
# Installed Funz design Brent

# %%
# find the `convection` value leading to `min(T) = 25.2` (with relative precision of 0.01 on `convection` value)
RunDesign(model="Modelica",input.files="NewtonCooling.mo.par", input.variables=list(convection="[0.5,1.0]"), output.expressions="min(T)", 
          design="Brent", design.options=list(ytarget=25.2, ytol=0.01))
# Out:
# Using archive directory: /content
#  Over.
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# Warning message in doTryCatch(return(expr), name, parentenv, handler):
# “NAs introduced by coercion”
# $convection
# $convection[[1]]
# $convection[[1]][[1]]
# [1] "Java-Object{0.5}"
#
# $convection[[1]][[2]]
# [1] "Java-Object{1.0}"
#
# $convection[[1]][[3]]
# [1] "Java-Object{1.0}"
#
# $convection[[1]][[4]]
# [1] "Java-Object{1.0}"
#
# $convection[[1]][[5]]
# [1] "Java-Object{0.90666177523769}"
#
# $convection[[1]][[6]]
# [1] "Java-Object{0.5}"
#
# $convection[[1]][[7]]
# [1] "Java-Object{0.90666177523769}"
#
# $convection[[1]][[8]]
# [1] "Java-Object{0.703330887618845}"
#
# $convection[[1]][[9]]
# [1] "Java-Object{0.5}"
#
# $convection[[1]][[10]]
# [1] "Java-Object{0.703330887618845}"
#
# $convection[[1]][[11]]
# [1] "Java-Object{0.6966263916546922}"
#
# $convection[[1]][[12]]
# [1] "Java-Object{0.5}"
#
#
#
# $`min(T)`
# $`min(T)`[[1]]
# $`min(T)`[[1]][[1]]
# [1] 25.98653
#
# $`min(T)`[[1]][[2]]
# [1] 25.01947
#
# $`min(T)`[[1]][[3]]
# [1] 25.01947
#
# $`min(T)`[[1]][[4]]
# [1] 25.01947
#
# $`min(T)`[[1]][[5]]
# [1] 25.03853
#
# $`min(T)`[[1]][[6]]
# [1] 25.98653
#
# $`min(T)`[[1]][[7]]
# [1] 25.03853
#
# $`min(T)`[[1]][[8]]
# [1] 25.19406
#
# $`min(T)`[[1]][[9]]
# [1] 25.98653
#
# $`min(T)`[[1]][[10]]
# [1] 25.19406
#
# $`min(T)`[[1]][[11]]
# [1] 25.20491
#
# $`min(T)`[[1]][[12]]
# [1] 25.98653
#
#
#
# $analysis
# $analysis[[1]]
# [1] "<HTML name=\"Root\">in iteration number 4.<br/>the root approximation is 0.696626391654692.<br/>corresponding to the value 25.2049114818065<br/><img src=\"./lt4.png\" width=\"600\" height=\"600\"/><br/>Exit due to algorithm converged<br/></HTML><root>0.696626391654692</root>"
#
#
# $root
# $root[[1]]
# [1] 0.6966264
#
#
# $Root.HTML
# $Root.HTML[[1]]
# [1] "in iteration number 4.<br/>the root approximation is 0.696626391654692.<br/>corresponding to the value 25.2049114818065<br/><img src=\"./lt4.png\" width=\"600\" height=\"600\"/><br/>Exit due to algorithm converged<br/>"
